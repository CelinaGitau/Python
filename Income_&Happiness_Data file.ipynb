# %% [markdown]
# <a href="https://colab.research.google.com/github/CelinaGitau/Python/blob/main/Income_%26Happiness_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
data = files.upload ()
# Out:
#      <input type="file" id="files-de866da9-b45a-4a77-a4e0-7301a8532ce2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-de866da9-b45a-4a77-a4e0-7301a8532ce2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
income_data = pd.read_csv ('income.datascatterplot.csv')

# %%
income_data
# Out:
#        income  happiness
# 0    3.862647   2.314489
# 1    4.979381   3.433490
# 2    4.923957   4.599373
# 3    3.214372   2.791114
# 4    7.196409   5.596398
# ..        ...        ...
# 506  3.440847   2.070664
# 507       NaN   3.710193
# 508  6.087610        NaN
# 509  3.440847   2.070664
# 510  4.530545   3.710193
#
# [511 rows x 2 columns]

# %%
income_data.plot (x='income', y= 'happiness', kind = 'scatter', color = 'orange')
# Out:
# <Axes: xlabel='income', ylabel='happiness'>

# %%
income_data.plot (x='income', y= 'happiness')
# Out:
# <Axes: xlabel='income'>

# %%
income_data.plot (x='income', y= 'happiness', kind = 'scatter', color = 'orange')
# Out:
# <Axes: xlabel='income', ylabel='happiness'>

# %%
import pandas as pd
from google.colab import files
data = files.upload()
income_data = pd.read_csv('income.datascatterplot.csv')
import seaborn as sns
sns.regplot (data =income_data, x='income', y= 'happiness', color = 'green')
# Out:
#      <input type="file" id="files-503f2203-b0ac-445e-8a77-520f9b5800e5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-503f2203-b0ac-445e-8a77-520f9b5800e5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
